# %% [markdown]
# <a href="https://colab.research.google.com/github/jmar008/AI4Devs-lab-google-colab/blob/main/HelloWorld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
# !pip install numpy matplotlib

# %% [markdown]
# Realizar Operaciones Básicas

# %%
import numpy as np
# Crear un arreglo de números
numeros = np.array([1, 2, 3, 4, 5])
# Operaciones básicas
suma = np.sum(numeros)
media = np.mean(numeros)
maximo = np.max(numeros)

print("Suma:", suma)
print("Media:", media)
print("Máximo:", maximo)
# Out:
# Suma: 15
# Media: 3.0
# Máximo: 5

# %% [markdown]
# Crear una Lista y Realizar Operaciones

# %%
# Crear una lista de números

numeros = [1, 2, 3, 4, 5]



# Imprimir la lista original

print("Lista original:", numeros)



  # Añadir un nuevo número a la lista

numeros.append(6)

print("Lista después de añadir un número:", numeros)



  # Eliminar un número de la lista

numeros.remove(3)

print("Lista después de eliminar un número:", numeros)



  # Ordenar la lista

numeros.sort()

print("Lista ordenada:", numeros)
# Out:
# Lista original: [1, 2, 3, 4, 5]
# Lista después de añadir un número: [1, 2, 3, 4, 5, 6]
# Lista después de eliminar un número: [1, 2, 4, 5, 6]
# Lista ordenada: [1, 2, 4, 5, 6]

# %% [markdown]
# ## **Uso de Comandos Especiales de Jupyter Notebook**
# Los notebooks de Jupyter tienen comandos especiales llamados "magics" que nos permiten realizar tareas específicas. Aquí usaremos algunos de ellos.
#
# **a. Mostrar el Tiempo de Ejecución**
#
# Utiliza %%time para medir el tiempo de ejecución de una celda completa.

# %%
# %%time
# Código cuya ejecución queremos medir
suma = 0
for i in range(1, 1000000):
  suma += i
  print(suma)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# 495014987503
# 495015982506
# 495016977510
# 495017972515
# 495018967521
# 495019962528
# 495020957536
# 495021952545
# 495022947555
# 495023942566
# 495024937578
# 495025932591
# 495026927605
# 495027922620
# 495028917636
# 495029912653
# 495030907671
# 495031902690
# 495032897710
# 495033892731
# 495034887753
# 495035882776
# 495036877800
# 495037872825
# 495038867851
# 495039862878
# 495040857906
# 495041852935
# 495042847965
# 495043842996
# 495044838028
# 495045833061
# 495046828095
# 495047823130
# 495048818166
# 495049813203
# 495050808241
# 495051803280
# 495052798320
# 495053793361
# 495054788403
# 495055783446
# 495056778490
# 495057773535
# 495058768581
# 495059763628
# 495060758676
# 495061753725
# 495062748775
# 495063743826
# 495064738878
# 495065733931
# 495066728985
# 495067724040
# 495068719096
# 495069714153
# 495070709211
# 495071704270
# 495072699330
# 495073694391
# 495074689453
# 495075684516
# ...

# %% [markdown]
# **b. Mostrar Gráficas en Línea**
#
# Utiliza %matplotlib inline para asegurarte de que las gráficas se muestren directamente en el notebook.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
 # Datos para graficar

x = np.linspace(0, 2 * np.pi, 100)

y = np.sin(x)



# Crear la gráfica

plt.plot(x, y)

plt.title("Seno de x")

plt.xlabel("x")

plt.ylabel("sin(x)")

plt.show()

# %% [markdown]
# # **Cargar Datos desde Google Drive**
# Google Colab permite montar tu Google Drive para acceder a archivos directamente desde tu unidad.

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
